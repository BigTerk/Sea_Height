# %%
# Classic imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Gotta zip these together and get the the number of unique observations per sheet 
# they are all in order and juet gotta be multiplied by the . size of wach sheet


City = ["Cape May", "Sandy Hook", "Atlantic City", "Montauk", "Woods Hole", "Chatham", "Fort Point", "Bar Harbor",
        "Lewes", "Ocean City Inlet", "Duck", "Oregon Inlet", "Wrightsville Beach", "Springmaid", "Charleston", 
        "Fort Pulaski", "Mayport", "Lake Worth Pier", "Virginia Key", "Key West", "Naples", "Clearwater", 
        "Cedar Key", "Panama City Beach", "Dauphin Island", "Bay Wave Land", "Shell Beach", "Pilots Station", 
        "Eugene Island", "Calcasieu", "Texas Point", "Galveston Bay", "Matagorda Bay", "Aransas", "Bob Hall Pier", 
        "SPIBrazoSantiago"]

State = ["NJ", "NJ", "NJ", "NY", "MA", "MA", "NH", "ME", "DE", "DE", "NC",
         "NC", "NC", "SC", "SC", "GA", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", 
         "AL", "MS", "LA", "LA", "LA", "LA", "TX", "TX", "TX", "TX", "TX", "TX"]

Station =[ 8536110, 8531680, 8534720, 8510560, 8447930, 8447435, 8423898,
           8413320, 8557380, 8570283, 8651370, 8652587, 8658163, 8661070, 
           8665530, 8670870, 8720218, 8722670, 8723214, 8724580, 8725110,
           8726724, 8727520, 8729210, 8735180, 8747437, 8761305, 8760922,
           8764314, 8768094, 8770822, 8771341, 8773767, 8775241, 8775870,
           8779749 ]

# %%
# Read in the Sheets 

# test it
#df1 = pd.read_excel(xls, 'Sheet1')
#df2 = pd.read_excel(xls, 'Sheet2')


# Real way 
xls = pd.ExcelFile('C:\\Users\\gst8882\\Desktop\\NOAA_Test.xlsx')
# make a list with each sheet as an item in the list
#df_list = []
df_list=pd.DataFrame()
# loop through the sheets
for i in range(1,37):
    #Sheet numbers
    s = 'Sheet'+str(i)    
    #Build the list 
    #df_list.append(pd.read_excel(xls, s))
    Raw = pd.read_excel(xls, s)
    
    Raw["City"]=[City[i-1]]*Raw.shape[0]
    Raw["State"]=[State[i-1]]*Raw.shape[0]
    Raw["Station"]=[Station[i-1]]*Raw.shape[0]
    
    if i ==1:
        df_list= Raw
    else:
        df_list=pd.concat([df_list, Raw])

# %%
df_list
# Out:
#            DateTime  WaterLevel Type  I  L              City State  Station
# 0     722816.362500       0.442   L   0  0          Cape May    NJ  8536110
# 1     722816.637500       2.509   HH  0  0          Cape May    NJ  8536110
# 2     722816.883333       0.378   LL  0  0          Cape May    NJ  8536110
# 3     722817.158333       2.158   H   0  0          Cape May    NJ  8536110
# 4     722817.408333       0.405   LL  0  0          Cape May    NJ  8536110
# 5     722817.675000       2.438   HH  0  0          Cape May    NJ  8536110
# 6     722817.920833       0.543   L   0  0          Cape May    NJ  8536110
# 7     722818.170833       1.981   H   0  0          Cape May    NJ  8536110
# 8     722818.458333       0.335   L   0  0          Cape May    NJ  8536110
# 9     722818.712500       1.932   HH  0  0          Cape May    NJ  8536110
# 10    722818.979167       0.268   LL  0  0          Cape May    NJ  8536110
# 11    722819.241667       1.932   H   0  0          Cape May    NJ  8536110
# 12    722819.491667       0.375   L   0  0          Cape May    NJ  8536110
# 13    722819.754167       2.036   HH  0  0          Cape May    NJ  8536110
# 14    722820.008333       0.277   LL  0  0          Cape May    NJ  8536110
# 15    722820.275000       1.811   H   0  0          Cape May    NJ  8536110
# 16    722820.520833       0.351   LL  0  0          Cape May    NJ  8536110
# 17    722820.787500       1.850   H   0  0          Cape May    NJ  8536110
# 18    722821.045833       0.415   L   0  0          Cape May    NJ  8536110
# 19    722821.329167       2.021   HH  0  0          Cape May    NJ  8536110
# 20    722821.575000       0.658   LL  0  0          Cape May    NJ  8536110
# 21    722821.850000       2.006   H   0  0          Cape May    NJ  8536110
# 22    722822.087500       0.725   L   0  0          Cape May    NJ  8536110
# 23    722822.362500       2.216   HH  0  0          Cape May    NJ  8536110
# 24    722822.608333       0.890   L   0  0          Cape May    NJ  8536110
# 25    722822.879167       2.082   H   0  0          Cape May    NJ  8536110
# 26    722823.129167       0.832   LL  0  0          Cape May    NJ  8536110
# 27    722823.395833       2.310   HH  0  0          Cape May    NJ  8536110
# 28    722823.687500       0.689   L   0  0          Cape May    NJ  8536110
# 29    722823.933333       1.850   H   0  0          Cape May    NJ  8536110
# ...             ...         ...  ... .. ..               ...   ...      ...
# 985   737109.179167       7.700   L   0  0  SPIBrazoSantiago    TX  8779749
# 986   737109.366667       7.756   H   0  0  SPIBrazoSantiago    TX  8779749
# 987   737109.691667       7.453   LL  0  0  SPIBrazoSantiago    TX  8779749
# 988   737110.000000       7.717   H   0  0  SPIBrazoSantiago    TX  8779749
# 989   737110.187500       7.651   L   0  0  SPIBrazoSantiago    TX  8779749
# 990   737110.454167       7.786   HH  0  0  SPIBrazoSantiago    TX  8779749
# 991   737110.720833       7.608   LL  0  0  SPIBrazoSantiago    TX  8779749
# 992   737110.983333       7.802   HH  0  0  SPIBrazoSantiago    TX  8779749
# 993   737111.208333       7.664   LL  0  0  SPIBrazoSantiago    TX  8779749
# 994   737111.500000       7.829   H   0  0  SPIBrazoSantiago    TX  8779749
# 995   737111.804167       7.717   L   0  0  SPIBrazoSantiago    TX  8779749
# 996   737112.020833       7.846   HH  0  0  SPIBrazoSantiago    TX  8779749
# 997   737112.270833       7.649   LL  0  0  SPIBrazoSantiago    TX  8779749
# 998   737112.541667       7.855   HH  0  0  SPIBrazoSantiago    TX  8779749
# 999   737112.829167       7.753   L   0  0  SPIBrazoSantiago    TX  8779749
# 1000  737113.000000       7.807   H   0  0  SPIBrazoSantiago    TX  8779749
# 1001  737113.270833       7.540   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1002  737114.029167       7.886   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1003  737114.379167       7.473   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1004  737114.883333       7.931   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1005  737115.379167       7.413   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1006  737115.991667       7.945   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1007  737116.420833       7.537   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1008  737116.854167       7.983   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1009  737117.462500       7.388   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1010  737117.937500       7.994   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1011  737118.516667       7.417   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1012  737118.904167       8.000   HH  0  0  SPIBrazoSantiago    TX  8779749
# 1013  737119.558333       7.440   LL  0  0  SPIBrazoSantiago    TX  8779749
# 1014  737119.929167       7.971   H   0  0  SPIBrazoSantiago    TX  8779749
#
# [1089996 rows x 8 columns]

# %%
# Build a CSV
df_list.to_csv("C:\\Users\\gst8882\\Desktop\\NOAA.csv", index = False)

# %%
# Check for any missing 
sns.heatmap(df_list.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
Water = pd.read_csv("C:\\Users\\gst8882\\Desktop\\NOAA.csv")

# %%
Water.head()
# Out:
#         DateTime  WaterLevel Type  I  L      City State  Station
# 0  722816.362500       0.442   L   0  0  Cape May    NJ  8536110
# 1  722816.637500       2.509   HH  0  0  Cape May    NJ  8536110
# 2  722816.883333       0.378   LL  0  0  Cape May    NJ  8536110
# 3  722817.158333       2.158   H   0  0  Cape May    NJ  8536110
# 4  722817.408333       0.405   LL  0  0  Cape May    NJ  8536110

# %%
from datetime import datetime, timedelta
temp_list = Water['DateTime']
another_list =[]
for i in temp_list:
    matlab_datenum = i
    python_datetime = datetime.fromordinal(int(matlab_datenum)) + timedelta(days=matlab_datenum%1) - timedelta(days = 366)
    another_list.append(python_datetime)

# %%
#another_list
temp_series = pd.Series(another_list)
Water=pd.concat([Water, temp_series],axis=1)
Water.head()
# Out:
#    WaterLevel Type      City State  Station                       Date  \
# 0       0.442   L   Cape May    NJ  8536110 1979-01-01 08:42:00.000004
# 1       2.509   HH  Cape May    NJ  8536110 1979-01-01 15:17:59.999996
# 2       0.378   LL  Cape May    NJ  8536110 1979-01-01 21:11:59.999997
# 3       2.158   H   Cape May    NJ  8536110 1979-01-02 03:47:59.999999
# 4       0.405   LL  Cape May    NJ  8536110 1979-01-02 09:47:59.999999
#
#                            0
# 0 1979-01-01 08:42:00.000004
# 1 1979-01-01 15:17:59.999996
# 2 1979-01-01 21:11:59.999997
# 3 1979-01-02 03:47:59.999999
# 4 1979-01-02 09:47:59.999999

# %%
Water.rename(columns={0:'Date'}, inplace=True)
Water= Water.drop(['DateTime', 'I', 'L'], axis=1)
Water.head()
# Out:
#    WaterLevel Type      City State  Station                       Date  \
# 0       0.442   L   Cape May    NJ  8536110 1979-01-01 08:42:00.000004
# 1       2.509   HH  Cape May    NJ  8536110 1979-01-01 15:17:59.999996
# 2       0.378   LL  Cape May    NJ  8536110 1979-01-01 21:11:59.999997
# 3       2.158   H   Cape May    NJ  8536110 1979-01-02 03:47:59.999999
# 4       0.405   LL  Cape May    NJ  8536110 1979-01-02 09:47:59.999999
#
#                         Date
# 0 1979-01-01 08:42:00.000004
# 1 1979-01-01 15:17:59.999996
# 2 1979-01-01 21:11:59.999997
# 3 1979-01-02 03:47:59.999999
# 4 1979-01-02 09:47:59.999999

# %%
Water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089996 entries, 0 to 1089995
# Data columns (total 6 columns):
# WaterLevel    1089996 non-null float64
# Type          1089996 non-null object
# City          1089996 non-null object
# State         1089996 non-null object
# Station       1089996 non-null int64
# Date          1089996 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.9+ MB

# %%
Water.to_csv("C:\\Users\\gst8882\\Desktop\\Sea_Height.csv", index = False)

# %%
Water['mean'] = Water[['WaterLevel']].mean(axis=1)
Water.head()
# Out:
#    WaterLevel Type      City State  Station                        Date   mean
# 0       0.442   L   Cape May    NJ  8536110  1979-01-01 08:42:00.000004  0.442
# 1       2.509   HH  Cape May    NJ  8536110  1979-01-01 15:17:59.999996  2.509
# 2       0.378   LL  Cape May    NJ  8536110  1979-01-01 21:11:59.999997  0.378
# 3       2.158   H   Cape May    NJ  8536110  1979-01-02 03:47:59.999999  2.158
# 4       0.405   LL  Cape May    NJ  8536110  1979-01-02 09:47:59.999999  0.405

# %%
Water['WaterLevel'].mean()
# Out:
# 3.136137028942999

# %% [markdown]
# # Extra and Test Stuff

# %%
# Create a new column for each City and State and Station 
# Pull out the index of the list above and multiply by the shape of the corresponding Data Frame(sheet)

df1["City"]=[City[0]]*df1.shape[0]
df1["State"]=[State[0]]*df1.shape[0]
df1["Station"]=[Station[0]]*df1.shape[0]
df1.head()

#It works... now do it in a loop
# Out:
#         DateTime  WaterLevel Type  I  L      City State  Station
# 0  722816.362500       0.442   L   0  0  Cape May    NJ  8536110
# 1  722816.637500       2.509   HH  0  0  Cape May    NJ  8536110
# 2  722816.883333       0.378   LL  0  0  Cape May    NJ  8536110
# 3  722817.158333       2.158   H   0  0  Cape May    NJ  8536110
# 4  722817.408333       0.405   LL  0  0  Cape May    NJ  8536110

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54428 entries, 0 to 54427
# Data columns (total 8 columns):
# DateTime      54428 non-null float64
# WaterLevel    54428 non-null float64
# Type          54428 non-null object
# I             54428 non-null int64
# L             54428 non-null int64
# City          54428 non-null object
# State         54428 non-null object
# Station       54428 non-null int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 3.3+ MB
